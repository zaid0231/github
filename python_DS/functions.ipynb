# %% [markdown]
# USER DEFINED FUNCTION

# %%
def greet ():
    print("hello man")

# %%
greet()
# Out:
# hello man

# %% [markdown]
# parameterized function

# %%
def sum (a, b):
   print(a + b)
sum(3,9)
# Out:
# 12

# %%
def avg(a,b,c,d):
    average = (a+b+c+d)/4
    return average

avg(2,4,6,8)
# Out:
# 5.0

# %%
def myCountry(country = "Norway"):
    print("I am from " + country)   


myCountry("Sweden")
myCountry()
# Out:
# I am from Sweden
# I am from Norway

# %%
#lambda function
x = lambda a : a + 10 
print(x(5))
# Out:
# 15

# %%
check_odd_even = lambda a: a%2 ==0
if (check_odd_even(4)):
    print("even")
else:
    print("odd")
# Out:
# even

# %%
even = lambda n : print ("even") if n%2 == 0 else print('odd') 
even(9)
# Out:
# odd

# %%
# practice problems

def is_leap_year(year):
  
    if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
            print(yr, "is a Leap Year.")

    else:
            print(yr, "is NOT a Leap Year.")

yr = int(input("Enter a year: "))
is_leap_year(yr)
# Out:
# 43 is NOT a Leap Year.

# %%
def is_prime(n):
    if n <2:
         print( "is NOT a Prime number.")

    for i in range(2, n):   
        if n % i == 0:
           print( "is NOT a Prime number.")
           break
        else:
         print( "is a Prime number.")
         break



num = int(input("Enter a number: "))

is_prime(num)
# Out:
# is a Prime number.

# %%
a = 'Python is great'
print
