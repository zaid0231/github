# %%
# if else statement
age = int(input("Enter your age: "))
if (age < 18):
    print("not eligible to vote")
else:
    print("eligible to vote")
# Out:
# not eligible to vote

# %%
# wap to choose a pizza topping 

topping = input("choose the pizza topping (paneer, mushroom, or onion):")

if topping == "paneer" or topping == "Paneer" or topping == "PANEER":
   print("you choose paneer topping")
elif topping == "mashroom" or topping == "Mashroom" or topping == "MASHROOM":
   print("you choose mashroom topping")
elif topping == "onion" or topping == "Onion" or topping == "ONION":
   print("you choose the topping onion ")
else:
   print("Invalid topping choice . please choose paneer , mashroom, or onion")
# Out:
# you choose the topping onion

# %%
# wap to check if the number is even or odd
num = int(input("Enter a number:"))
if num % 2 == 0:
    print("the number is even")
else:
    print("the number is odd")
# Out:
# the number is odd

# %%
# Wap to find largest of three numbers
num1 = int(input("Enter first number: "))   
num2 = int(input("enter second number"))
num3 = int(input("Enter the third number"))
if num1 >= num2 and num1 >= num3:
    print("the largest number is", num1)
elif num2>= num1 and num2 >= num3:
    print("the largest number is", num2)
else:
    print("the largest number is", num3)
# Out:
# the largest number is 9
