# %%
s = "Hello, World! This is a string. and this is another string."
words = s.split()  
print(words)
# Out:
# ['Hello,', 'World!', 'This', 'is', 'a', 'string.', 'and', 'this', 'is', 'another', 'string.']

# %%
s.capitalize()
# Out:
# 'Hello, world! this is a string. and this is another string.'

# %%
s.upper()
# Out:
# 'HELLO, WORLD! THIS IS A STRING. AND THIS IS ANOTHER STRING.'

# %%
s.lower()
# Out:
# 'hello, world! this is a string. and this is another string.'

# %% [markdown]
# Multi-line string

# %%
poem = '''Roses are red,
Violets are blue,
Python is great,'''
print(poem)
# Out:
# Roses are red,
# Violets are blue,
# Python is great,

# %%
a = 'Python is great'
print(a[-1])
a.split()
r = a[0:]
print(r,end="  ")
# Out:
# t
# Python is great

# %%
words = ['Python', 'is', 'easy', 'to', 'learn']
result_string =  " ".join(words)
print(result_string)
# Out:
# Python is easy to learn
