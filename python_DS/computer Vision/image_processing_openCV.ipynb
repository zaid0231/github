# %%
import cv2

# %%
Image=cv2.imread('myimage.jpg')

# %%
if Image is None:
    cv2.imshow('Image',Image)
    cv2.waitKey(0) # Wait for a key press to close the window
    cv2.destroyAllWindows() # Close all windows

# %%
gray_image = cv2.cvtColor(Image, cv2.COLOR_BGR2GRAY)
cv2.imshow('Gray Image', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
blurred_image = cv2.GaussianBlur(Image, (17,17), 0)
cv2.imshow('Blurred Image', blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# image croping
croped_image= image[50:200, 100:300]
cv2.imshow('Cropped Image', croped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # image croping
# ----> 2 croped_image= image[50:200, 100:300]
#       3 cv2.imshow('Cropped Image', croped_image)
#       4 cv2.waitKey(0)
#
# NameError: name 'image' is not defined

# %%
image.shape

# %%
#image resizing
resized_image=cv2.resize(Image,(500,500))
cv2.imshow('Resized Image',resized_image)
cv2.waitKey(0)      
cv2.destroyAllWindows()

# %%
# draw rectangle on image
cv2.rectangle(Image,(100,100),(300,300),(0,255,0),3)
cv2.imshow('Image with Rectangle',Image)
cv2.waitKey(0)
cv2.destroyAllWindows()
