# %%
import math

# %%
print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 4.0
# 120

# %%
from random import random, randint, choice, shuffle

# %%
print("Get a number between 0 and 1", random())
print("Get a random integer between 1 and 10:", randint(1, 10))
print("Get a random choice from a list:", choice(['apple', 'banana', 'cherry']))
names = ['Alice', 'Bob', 'Charlie', 'David']
shuffle(names)
print(names)
# Out:
# Get a number between 0 and 1 0.8595332384031873
# Get a random integer between 1 and 10: 2
# Get a random choice from a list: cherry
# ['David', 'Charlie', 'Alice', 'Bob']

# %%
from datetime  import datetime as td

# %%
print(f"Current date and time: {td.now()}")
print(f"current date: {td.now().date()}")
# Out:
# Current date and time: 2025-08-30 10:54:39.956614
# current date: 2025-08-30
