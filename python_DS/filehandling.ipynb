# %%
file = open('text.txt','r')
print(file.read())
# Out:
# hello zaid
# yo what up

# %%
file = open('text.txt', 'w')
file.write('hello zaid')
print('file written successfully')
file = open('text.txt', 'r')
print(file.read())
# Out:
# file written successfully
# hello zaid

# %%
file = open('text.txt', 'a')
file.write('\nyo what up\n')
file = open('text.txt', 'r')
print(file.read())
# Out:
# hello zaid
# yo what up

# %%
import os
print(os.getcwd())
# Out:
# /Users/zaydie/Desktop/github/python

# %%
files = os.listdir()
print(" Files in directory ",files)
# Out:
#  Files in directory  ['conditions.ipynb', 'Data Structures', 'c.cpp', 'DataTypes.ipynb', 'tempCodeRunnerFile.ipynb', 'operators.ipynb', 'filehandling.ipynb', 'loops.ipynb', 'functions.ipynb', 'text.txt', 'c', 'assingment.ipynb']
